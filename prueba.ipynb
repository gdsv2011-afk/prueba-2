# %% [markdown]
# <a href="https://colab.research.google.com/github/gdsv2011-afk/prueba-2/blob/main/prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("mundial 2026 ")
# Out:
# mundial 2026

# %%
Jugador="Little Mac"
print(Jugador,"Ha ertado a la arena ")
Jugador2="Kirby"
print(Jugador2,"se ha caaido del ecenario")
# Out:
# Little Mac Ha ertado a la arena
# Kirby se ha caaido del ecenario
